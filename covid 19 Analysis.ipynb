# %% [markdown]
# # Import All modul

# %%
import bs4
import numpy as np
import pandas as pd
import urllib.request
import requests
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import urllib.request,urllib.parse,urllib.error
import geopandas as gpd

# %%
#open link for web scraping
url="https://www.mohfw.gov.in/"

# %%
html=urllib.request.urlopen(url)

# %%
soup=BeautifulSoup(html)

# %%
all_rows=soup.findAll('tr')

# %%
#remove All \n from data
def remove_extra(row):
    return[x.text.replace('\n','')for x in row]

# %%
states=[]
for row in all_rows:
    st=remove_extra(row.findAll('td'))
    if len(st)==6:
        states.append(st)

# %%
new_cols=["Sr","States","confirmed","Recovered","death","total"]

# %%
df=pd.DataFrame(data=states,columns=new_cols)

# %%
df=df.drop('total',axis=1)

# %%
df= df.drop(index=[35,36])

# %%
df
# Out:
#     Sr                                    States confirmed Recovered death
# 0    1               Andaman and Nicobar Islands        72        75     0
# 1    2                            Andhra Pradesh     11200      9745   252
# 2    3                         Arunachal Pradesh       169       105     2
# 3    4                                     Assam      4179      8329    14
# 4    5                                     Bihar      3182      9284   104
# 5    6                                Chandigarh        86       401     7
# 6    7                              Chhattisgarh       650      2751    14
# 7    8  Dadra and Nagar Haveli and Daman and Diu       222       183     0
# 8    9                                     Delhi     25449     74217  3165
# 9   10                                       Goa       739      1156     8
# 10  11                                   Gujarat      8853     26720  1977
# 11  12                                   Haryana      4075     13645   279
# 12  13                          Himachal Pradesh       282       790    11
# 13  14                         Jammu and Kashmir      3389      5399   143
# 14  15                                 Jharkhand       870      2104    22
# 15  16                                 Karnataka     15301     11098   416
# 16  17                                    Kerala      2415      3452    27
# 17  18                                    Ladakh       204       836     1
# 18  19                            Madhya Pradesh      3237     11768   622
# 19  20                               Maharashtra     89313    118558  9250
# 20  21                                   Manipur       659       771     0
# 21  22                                 Meghalaya        36        43     1
# 22  23                                   Mizoram        64       133     0
# 23  24                                  Nagaland       382       243     0
# 24  25                                    Odisha      3352      6703    42
# 25  26                                Puducherry       482       434    14
# 26  27                                    Punjab      2020      4554   175
# 27  28                                 Rajasthan      4357     16575   472
# 28  29                                    Sikkim        55        70     0
# 29  30                                Tamil Nadu     45842     71116  1636
# 30  31                                 Telangana     11012     16287   313
# 31  32                                   Tripura       455      1248     1
# 32  33                               Uttarakhand       566      2621    43
# 33  34                             Uttar Pradesh      9514     19627   827
# 34  35                               West Bengal      7243     15790   804

# %%
plt.figure(figsize=(40,20))
plt.xticks(fontsize=20)
plt.yticks(fontsize=25)
plt.xlabel('States',fontsize=30)
plt.ylabel('confirmed',fontsize=30)
plt.bar(df['States'],df['confirmed'],color='red')
plt.show()

# %%
data_map= gpd.read_file('importfile\Indian_States.shp')
data_map.plot()

# %%
print(data_map.columns[0])
print(df.columns[1])
# Out:
# st_nm
# States

# %%
#data_map.rename(columns={'st_nm':'States'},inplace=True)
data_map.rename(columns={'st_nm':'States'},inplace=True )

# %%
data_map['States']=data_map['States'].str.replace('&','and')
data_map['States'].iloc[0]='Andaman and Nicobar Islands'
data_map['States'].iloc[1]='Arunachal Pradesh'
data_map['States'].iloc[6]='Dadra Nagar Haveli and Daman and Diu'
data_map['States'].iloc[23]='Delhi'
data_map['States'].iloc[29]='Telangana'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
merged=pd.merge(data_map,df,on='States')

# %%
merged
# Out:
#                          States  \
# 0   Andaman and Nicobar Islands
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                    Chandigarh
# 5                  Chhattisgarh
# 6                           Goa
# 7                       Gujarat
# 8                       Haryana
# 9              Himachal Pradesh
# 10            Jammu and Kashmir
# 11                    Jharkhand
# 12                    Karnataka
# 13                       Kerala
# 14               Madhya Pradesh
# 15                  Maharashtra
# 16                      Manipur
# 17                    Meghalaya
# 18                      Mizoram
# 19                     Nagaland
# 20                        Delhi
# 21                   Puducherry
# 22                       Punjab
# 23                    Rajasthan
# 24                       Sikkim
# 25                   Tamil Nadu
# 26                    Telangana
# 27                      Tripura
# 28                Uttar Pradesh
# 29                  Uttarakhand
# 30                  West Bengal
# 31                       Odisha
# 32               Andhra Pradesh
#
#                                              geometry  Sr confirmed Recovered  \
# 0   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...   1        72        75
# 1   POLYGON ((96.16261 29.38078, 96.16860 29.37432...   3       169       105
# 2   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...   4      4179      8329
# 3   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...   5      3182      9284
# 4   POLYGON ((76.84147 30.75996, 76.83599 30.73623...   6        86       401
# 5   POLYGON ((83.33532 24.09885, 83.35346 24.09627...   7       650      2751
# 6   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...  10       739      1156
# 7   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...  11      8853     26720
# 8   POLYGON ((76.85065 30.87512, 76.86594 30.86691...  12      4075     13645
# 9   POLYGON ((76.79634 33.25490, 76.80351 33.25275...  13       282       790
# 10  POLYGON ((74.73451 37.02068, 74.73647 37.01937...  14      3389      5399
# 11  POLYGON ((87.60582 25.31512, 87.61279 25.31184...  15       870      2104
# 12  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...  16     15301     11098
# 13  POLYGON ((74.99575 12.79227, 75.00006 12.78777...  17      2415      3452
# 14  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...  19      3237     11768
# 15  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...  20     89313    118558
# 16  POLYGON ((94.57602 25.64221, 94.57487 25.63858...  21       659       771
# 17  POLYGON ((91.85632 26.10353, 91.86717 26.09906...  22        36        43
# 18  POLYGON ((92.80022 24.41630, 92.80310 24.41603...  23        64       133
# 19  POLYGON ((95.21458 26.93095, 95.21719 26.92818...  24       382       243
# 20  POLYGON ((77.09361 28.86940, 77.10973 28.86722...   9     25449     74217
# 21  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...  26       482       434
# 22  POLYGON ((75.88469 32.48841, 75.90303 32.47169...  27      2020      4554
# 23  POLYGON ((73.89849 29.97896, 73.90021 29.97140...  28      4357     16575
# 24  POLYGON ((88.65381 28.09883, 88.66265 28.08956...  29        55        70
# 25  MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...  30     45842     71116
# 26  POLYGON ((81.05614 17.79097, 81.05834 17.75464...  31     11012     16287
# 27  POLYGON ((92.22108 24.50131, 92.22771 24.49862...  32       455      1248
# 28  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...  34      9514     19627
# 29  POLYGON ((79.21047 31.34846, 79.21386 31.34680...  33       566      2621
# 30  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...  35      7243     15790
# 31  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...  25      3352      6703
# 32  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...   2     11200      9745
#
#    death
# 0      0
# 1      2
# 2     14
# 3    104
# 4      7
# 5     14
# 6      8
# 7   1977
# 8    279
# 9     11
# 10   143
# 11    22
# 12   416
# 13    27
# 14   622
# 15  9250
# 16     0
# 17     1
# 18     0
# 19     0
# 20  3165
# 21    14
# 22   175
# 23   472
# 24     0
# 25  1636
# 26   313
# 27     1
# 28   827
# 29    43
# 30   804
# 31    42
# 32   252

# %%
merged.shape
# Out:
# (33, 6)

# %%
#ax = merged.plot()
fig, ax = plt.subplots(figsize  =(12, 10))
merged.plot(column='confirmed',ax=ax,cmap='YlGnBu',linewidth=1,edgecolor='0.3',legend=True)
ax.set_title("Confirmed Cases", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Confirmed Cases')

# %%
fig, ax = plt.subplots(figsize  =(12, 10))
merged.plot(column='death',ax=ax,cmap='BuGn',linewidth=1,edgecolor='0.3',legend=True)
ax.set_title("Death", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Death')

# %%
fig, ax = plt.subplots(figsize  =(12, 10))
merged.plot(column='Recovered',ax=ax,cmap='YlGn',linewidth=1,edgecolor='0.3',legend=True)
ax.set_title("Recovered Cases", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Recovered Cases')
